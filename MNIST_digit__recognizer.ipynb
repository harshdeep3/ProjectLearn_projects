# %% [markdown]
# <a href="https://colab.research.google.com/github/harshdeep3/ProjectLearn_projects/blob/main/MNIST_digit__recognizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch

# %%
import torch

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
#get training and testing data
train_data = datasets.MNIST(root='data', train=True, transform=ToTensor(), download=True)
test_data = datasets.MNIST(root='data', train=False, transform=ToTensor(), download=True)

# %%
train_data, test_data
# Out:
# (Dataset MNIST
#      Number of datapoints: 60000
#      Root location: data
#      Split: Train
#      StandardTransform
#  Transform: ToTensor(),
#  Dataset MNIST
#      Number of datapoints: 10000
#      Root location: data
#      Split: Test
#      StandardTransform
#  Transform: ToTensor())

# %%
train_data.data.size(), test_data.data.size()
# Out:
# (torch.Size([60000, 28, 28]), torch.Size([10000, 28, 28]))

# %%
import matplotlib.pyplot as plt

# %%
# visualising MNIST Data

plt.imshow(train_data.data[0], cmap='gray')
plt.title('%i' % train_data.targets[0])
plt.show()

# %%
#plot multiple images
figure = plt.figure(figsize=(10,8))
cols, rows = 5, 5
for i in range(1, cols * rows + 1):
  sample_idx = torch.randint(len(train_data), size=(1,)).item() # get random index
  img, label = train_data[sample_idx] # get image and label for index
  figure.add_subplot(rows, cols, i) # add to subplot
  plt.title(label)
  plt.axis("off")
  plt.imshow(img.squeeze(), cmap='gray')

plt.show()
